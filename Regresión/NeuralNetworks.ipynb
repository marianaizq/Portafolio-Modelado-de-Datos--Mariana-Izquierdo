# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg" width="350px" height="180px" />
#
#
# # <font color= #8A0829> Laboratorio de Modelado de Datos </font>
# #### <font color= #2E9AFE> `Martes y Viernes (Videoconferencia) de 13:00 - 15:00 hrs`</font>
# - <Strong> Sara Eugenia Rodríguez </Strong>
# - <Strong> Año </Strong>: 2025
# - <Strong> Email: </Strong>  <font color="blue"> `cd682324@iteso.mx` </font>
# ___
#
# <p style="text-align:right;"> Imagen recuperada de: https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg</p>
#
# ### <font color= #2E9AFE> Tema: Redes Neuronales</font>

# %% [markdown]
# Las redes neuronales profundas (deep learning) han ganado mucha popularidad en los últimos años, especialmente para problemas complejos, como el reconocimiento de imágenes, el procesamiento del lenguaje natural y otras aplicaciones que requieren modelos potentes.
#
# Sin embargo, las redes neuronales básicas también pueden usarse en problemas de aprendizaje supervisado más simples, como regresión o clasificación, AUNQUE hay varias razones por las cuales otros algoritmos son más comunes en estos casos...
#
# 1. Complejidad computacional
# 2. Sobreajuste (Overfitting)
# 3. Necesidad de más datos
# 4. Tuning de Hiperparámetros (las redes neuronales tienen muchos hiperparámetros)
# 5. Interpretabilidad, son modelos de caja negra
#
# **¿Cuándo se utilizan redes neuronales en aprendizaje supervisado?**
#
# Aunque no siempre son la primera opción para problemas simples, las redes neuronales pueden ser muy útiles en problemas supervisados más complejos donde:
#
# - Hay gran cantidad de datos disponibles
# - Los problemas son no lineales
# - Hay tareas de percepción involucradas (como visión por computadora, reconocimiento de voz o procesamiento de lenguaje natural), donde las redes neuronales profundas sobresalen.

# %% [markdown]
# Dentro de la caja negra...
#
# **¿Qué es una neurona?**
#
# Es un nombre elegante que le pusieron para referirse a una función en los años de 1940-1950. Se creeía que los nodos eran como neuronas del cerebro.
#
# **¿Qué es una función?**
#
# Es un nombre elegante que pusieron para referirse a algo que toma cosas de entrada, aplica alguna lógica y saca un resultado.
#
# **¿Qué es una red neuronal?**
#
# Es la interconexión de múltiples neuronas (funciones) para resolver un problema complejo que una sola neurona no podría. Dentro de los componentes existen *nodos* y *conexiones*
#
# **Pasos que hace la red neuronal:**
#
# 1. Combinación de las variables de entrada (X). Cada señal recibida tiene una constante w (peso/weight) que permite manipular la importancia de cada variable de entrada.
# 2. Neurona de respuesta. Considerando todas las variables de entrada, la neurona genera una señal de respuesta a través de una función.
#
# **Tipos de capas en la red neuronal**
#
# - Capa de entrada: capa que toma los datos de entrada
# - Capas ocultas: toman las entradas de otra capa y pasan a salida hacia otra capa (son intermediarias entre la entrada y la salida)
# - Capas de salida: capa que hace la predicción
#
# <img style="float: center; margin: 0px 0px 0px 0px;" src="https://www.smartsheet.com/sites/default/files/IC-simplified-artificial-neural-networks-corrected.svg" width="350px" height="180px" />

# %% [markdown]
# **Funciones de activación**
#
# El comportamiento de las neuronas de las redes neuronales es basado en la función en la que la neurona se especializó. Una neurona puede cambiar su respuesta dependiendo de la función de activación $\varphi(*)$ que sea seleccionada
#
# Funciones comunes:
# 1. Lineal: $\varphi(\nu)=\nu$
# 2. Sigmoidal: $\varphi(\nu)=\frac{e^{\nu}}{1+e^{\nu}}$
# 3. Tanh: $\varphi(\nu)=\frac{e^{\nu}-e^{-\nu}}{e^{\nu}+e^{-\nu}}=tanh(\nu)$
# 4. Softplus: $\varphi(\nu)=log(1+e^{\nu})$
# 5. RELU: $\varphi(\nu)=max(0,\nu)$
#
# Las funciones de activación suelen ser diferenciables, lo que significa que la derivada de primer orden se puede calcular para un valor de entrada dado. Esto es necesario dado que las redes neuronales generalmente se entrenan utilizando el algoritmo de backpropagation que requiere la derivada del error de predicción para actualizar los pesos del modelo.
#
# **¿Cómo elegir la función de activación para las capas ocultas?**
#
# - RELU: es la más utilizada para capas ocultas. Es fácil de calcular, lo que la hace más rápida para entrenar. Es simple de implementar y no es tan susceptible a gradientes que se desvanecen
# - Leaky RELU: Similar a ReLU, pero permite valores negativos pequeños cuando x≤0, lo que evita que las neuronas queden completamente inactivas.
# - Evita Sigmoid y Tanh en las capas ocultas
#
# **¿Cómo elegir la función de activación para las capas de salida?**
#
# - Lineal: Para problemas de regresión donde la salida es un valor continuo.
# - Sigmoidal: típicamente para problemas de clasificación binaria.
# - Softmax: Para problemas de clasificación multiclase
#
#
# **¿Cómo son las redes neuronales para regresión?**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# <font color= #2E9AFE>$$y^{2} = \varphi(\nu^{2})$$</font>
#
# La única diferencia es la última salida. La función de la salida tiene que ser **lineal**
#
#
# **¿Cómo elegir cuántas capas ocultas?**
#
# - Problemas sencillos: Una sola capa oculta suele ser suficiente para capturar patrones simples.
# - Problemas más complejos (con relaciones no lineales más complicadas): Dos capas ocultas pueden ser útiles
#
# En la práctica, la mayoría de los problemas sencillos no necesitan más de 1 o 2 capas ocultas.
#
# **¿Cómo elegir cuántas neuronas en las capas ocultas?**
#
# - Un buen punto de partida es comenzar con un número de neuronas que sea similar o cercano al número de características de entrada.
# - Para problemas simples, puedes comenzar con entre 4 y 16 neuronas por capa.
# - Si los datos tienen una cantidad moderada de complejidad o son no lineales, podrías aumentar a 32 o 64 neuronas en la capa oculta.
# - Evita tener muchas más neuronas que características de entrada, ya que eso puede llevar a un sobreajuste.
# - En redes con múltiples capas ocultas, una estrategia común es que las capas posteriores tengan menos neuronas que las capas iniciales. Esto es porque las primeras capas extraen más características, mientras que las capas más profundas se enfocan en combinarlas.
#
# **Recomendaciones**
#
# - Se recomienda hacer un pre-procesamiento de los datos - Escalamiento
# - Comúnmente todas las capas ocultas usan la misma función de activación
# - La función de salida generalmente usa diferente función de activación que el de las capas ocultas.
# - En la experiencia, conviene más aumentar el número de neuronas ocultas en lugar de aumentar el número de capas ocultas.
# - Se recomienda no usar muchas capas ocultas
#
#
# **¿Por qué el deep learning no funciona tan bien en problemas clásicos de regresión/clasificación?**
#
# Gran parte del éxito de las redes neuronales modernas proviene de su capacidad para explotar la naturaleza compositiva del mundo. Es decir, en problemas de percepción como el análisis de imágenes o audio, las características tienen un orden (espacial o temporal) y los patrones locales se agregan para formar conceptos y objetos de nivel superior (por ejemplo, la imagen de un automóvil está hecha de ruedas y otras partes, que están hechas de características visuales de nivel inferior, que están hechas de formas básicas como bordes, círculos y líneas, etc.).
#
# Las redes neuronales modernas, como las redes neuronales convolucionales (CNN), aprovechan esto aprendiendo características cada vez más abstractas en las capas más profundas.
#
# Por el contrario, los problemas de regresión clásicos constan de una serie de características no ordenadas, y el valor objetivo se puede predecir bastante bien con un modelo lineal/no lineal superficial de las características de entrada. En cierto sentido, esta propiedad composicional presente en problemas como la clasificación de imágenes o el reconocimiento de voz no está presente en problemas como "Predecir los ingresos de un individuo en función de su sexo, edad, nacionalidad, grado académico, tamaño de la familia...".

# %% [markdown]
# ## Ejemplo: Eficiencia de Energia
#
# Se busca analizar la eficiencia energética de los edificios.
#
# Se realizaron análisis energéticos utilizando 12 tipos de edificios diferentes simulados en Ecotect.
#
# Los edificios se diferencian en cuanto a la superficie con cristales, la distribución del área acristalada y la orientación, entre otros parámetros.
#
# Se simularon varios escenarios en función de las características antes mencionadas para obtener 768 formas de edificios.
#
# El conjunto de datos comprende 768 muestras y 8 características, con el objetivo de predecir dos respuestas con valor real.
#
# Información de atributos:
# - X1 Relative Compactness
# - X2 Surface Area
# - X3 Wall Area
# - X4 Roof Area
# - X5 Overall Height
# - X6 Orientation
# - X7 Glazing Area
# - X8 Glazing Area Distribution
#
# Targets:
# - Y1: Heating Load (in Wh)
# - Y2: Cooling Load (in Wh)
# -
# Las características son numéricas y representan diversas características físicas del edificio, mientras que las variables objetivo representan la energía necesaria para calefacción y enfriamiento.

# %%
#pip install tensorflow

# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.16.2

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ENB2012_data.csv")

df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    int64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    int64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
df.describe()
# Out:
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1          Y2
# count  768.000000  768.00000  768.000000  768.000000
# mean     0.234375    2.81250   22.307201   24.587760
# std      0.133221    1.55096   10.090196    9.513306
# min      0.000000    0.00000    6.010000   10.900000
# 25%      0.100000    1.75000   12.992500   15.620000
# 50%      0.250000    3.00000   18.950000   22.080000
# 75%      0.400000    4.00000   31.667500   33.132500
# max      0.400000    5.00000   43.100000   48.030000

# %%
#Matriz de correlaciones
correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
#Correlaciones con el target
correlation_target = df.corr()[['Y1','Y2']]
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_target, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Target')
plt.show()

# %%
#Distribucion de las varialbes
sns.pairplot(df)

# %% [markdown]
# ### Modelado

# %% [markdown]
# Vamos a usar una red compartida con dos salidas (cooling and heating load), ya que los dos targets están físicamente relacionados y la red puede aprender representaciones compartidas.
#
# Algunos tips para empezar la arquitectura inicial de la red:
#
# **a. Entrada y salida**
#
# - Entradas: 8 características → tamaño de capa de entrada = 8
# - Salidas: 2 objetivos → tamaño de capa de salida = 2
#
# **b. Capas ocultas**
#
# Por lo general, comienzas poco a poco y vas ampliando:
#
# - Comienza con 1 a 2 capas ocultas.
# - Numero de neuronas: entre el tamaño de entrada y salida (8) y tal vez entre 2 y 4 veces más (16–32–64).
#
# Por ejemplo:
# Input (8)
# ↓
# Dense(64, ReLU)
# ↓
# Dense(32, ReLU)
# ↓
# Dense(2, Linear)
#
# **c. Funcion de activacion**
#
# Comenzar con RELU para capas ocultas
#
# **d. Agregar Regularizacion**
#
# Agregar regularizacion si vemos overfitting (dropout)
#
# **e. Funcion de costo**
#
# MSE
#
# **f. Optimizer**
#
# Adam

# %%
X = df[['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8']].values
y1 = df['Y1'].values  # Heating Load
y2 = df['Y2'].values  # Cooling Load

# %%
X_train, X_test, y1_train, y1_test, y2_train, y2_test = train_test_split(X, y1, y2, test_size=0.2, random_state=42)

# %%
# Estandarizamos los datos
scaler=StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Modelo Baseline

# %%
# Capa de entrada (8 variables)
input_layer = Input(shape=(X_train.shape[1],), name='input_layer')

# Capas ocultas compartidas
layer_dense1_shared=Dense(64 , activation='relu', name='shared_dense_1')(input_layer)
layer_dense2_shared=Dense(32,activation='relu',name='shared_dense_2')(layer_dense1_shared)
layer_dropout1_shared=Dropout(0.2,name='shared_dropout_1')(layer_dense2_shared)

#Estructura para Y1 (Heating Load)
y1_dense_1=Dense(32, activation='relu',name='y1_dense_1')(layer_dropout1_shared)
y1_dropout = Dropout(0.2, name='y1_dropout')(y1_dense_1)
y1_dense2 = Dense(16, activation='relu', name='y1_dense_2')(y1_dropout)
y1_output = Dense(1, name='y1_output')(y1_dense2)

#Estructura para Y2 (Cooling Load)
y2_dense1 = Dense(32, activation='relu', name='y2_dense_1')(layer_dropout1_shared)
y2_dropout = Dropout(0.2, name='y2_dropout')(y2_dense1)
y2_dense3 = Dense(16, activation='relu', name='y2_dense_3')(y2_dropout)
y2_output = Dense(1, name='y2_output')(y2_dense3)
# Out:
# 2025-10-10 15:18:01.661923: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2025-10-10 15:18:01.662188: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-10-10 15:18:01.662601: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-10-10 15:18:01.663434: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-10-10 15:18:01.663934: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
#  Modelo que contenga la capa de entrada y las capas de salida 
model=Model(inputs=input_layer  ,outputs=[y1_output , y2_output])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dense_1      │ (None, 64)        │        576 │ input_layer[0][0] │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dense_2      │ (None, 32)        │      2,080 │ shared_dense_1[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dropout_1    │ (None, 32)        │          0 │ shared_dense_2[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dense_1 (Dense)  │ (None, 32)        │      1,056 │ shared_dropout_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dense_1 (Dense)  │ (None, 32)        │      1,056 │ shared_dropout_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dropout          │ (None, 32)        │          0 │ y1_dense_1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dropout          │ (None, 32)        │          0 │ y2_dense_1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dense_2 (Dense)  │ (None, 16)        │        528 │ y1_dropout[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dense_3 (Dense)  │ (None, 16)        │        528 │ y2_dropout[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_output (Dense)   │ (None, 1)         │         17 │ y1_dense_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_output (Dense)   │ (None, 1)         │         17 │ y2_dense_3[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,858 (22.88 KB)
#  Trainable params: 5,858 (22.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilamos el modelo

model.compile(optimizer='adam', 
              loss={'y1_output': 'mse', 'y2_output': 'mse'}, 
              metrics={'y1_output': 'mae', 'y2_output': 'mae'})

# Entrenamos el modelo
history = model.fit(X_train, [y1_train, y2_train], epochs=200, batch_size=32, 
                    validation_data=(X_test, [y1_test, y2_test]))
# Out:
# Epoch 1/200
# 2025-10-10 15:18:18.248938: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 1229.6554 - y1_output_loss: 569.4496 - y1_output_mae: 21.9825 - y2_output_loss: 670.1416 - y2_output_mae: 24.2550 - val_loss: 1259.8372 - val_y1_output_loss: 577.8099 - val_y1_output_mae: 22.4053 - val_y2_output_loss: 689.6653 - val_y2_output_mae: 24.8713
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1130.3031 - y1_output_loss: 505.4903 - y1_output_mae: 21.3965 - y2_output_loss: 613.0807 - y2_output_mae: 23.8199 - val_loss: 1090.8762 - val_y1_output_loss: 484.0609 - val_y1_output_mae: 21.3341 - val_y2_output_loss: 609.8918 - val_y2_output_mae: 23.9737
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1000.3541 - y1_output_loss: 430.8331 - y1_output_mae: 20.0707 - y2_output_loss: 562.9589 - y2_output_mae: 23.0590 - val_loss: 978.4088 - val_y1_output_loss: 420.9426 - val_y1_output_mae: 18.9301 - val_y2_output_loss: 552.7078 - val_y2_output_mae: 21.8917
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1235.8944 - y1_output_loss: 537.5862 - y1_output_mae: 19.9368 - y2_output_loss: 710.1545 - y2_output_mae: 22.9896 - val_loss: 1292.7239 - val_y1_output_loss: 519.7941 - val_y1_output_mae: 18.7572 - val_y2_output_loss: 763.5794 - val_y2_output_mae: 22.6857
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1392.3303 - y1_output_loss: 561.3488 - y1_output_mae: 20.3250 - y2_output_loss: 799.8185 - y2_output_mae: 24.1953 - val_loss: 1314.4221 - val_y1_output_loss: 576.2966 - val_y1_output_mae: 19.2846 - val_y2_output_loss: 729.7131 - val_y2_output_mae: 22.3130
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1490.1996 - y1_output_loss: 622.8378 - y1_output_mae: 21.3208 - y2_output_loss: 856.5221 - y2_output_mae: 24.8092 - val_loss: 1277.5234 - val_y1_output_loss: 553.9787 - val_y1_output_mae: 19.0745 - val_y2_output_loss: 716.3127 - val_y2_output_mae: 22.4067
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1575.2466 - y1_output_loss: 700.8193 - y1_output_mae: 21.8931 - y2_output_loss: 952.7546 - y2_output_mae: 25.5272 - val_loss: 1323.1740 - val_y1_output_loss: 537.3840 - val_y1_output_mae: 18.8244 - val_y2_output_loss: 778.6094 - val_y2_output_mae: 23.0138
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1863.3052 - y1_output_loss: 731.1030 - y1_output_mae: 22.2698 - y2_output_loss: 1136.2401 - y2_output_mae: 27.7350 - val_loss: 963.0259 - val_y1_output_loss: 335.4011 - val_y1_output_mae: 17.2688 - val_y2_output_loss: 624.7106 - val_y2_output_mae: 22.0468
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2558.0645 - y1_output_loss: 945.3120 - y1_output_mae: 25.1132 - y2_output_loss: 1551.7440 - y2_output_mae: 32.3507 - val_loss: 1256.5944 - val_y1_output_loss: 305.3875 - val_y1_output_mae: 16.8937 - val_y2_output_loss: 947.1930 - val_y2_output_mae: 24.8046
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3779.0435 - y1_output_loss: 1224.0247 - y1_output_mae: 28.1320 - y2_output_loss: 2502.8254 - y2_output_mae: 40.0865 - val_loss: 1540.2745 - val_y1_output_loss: 761.4935 - val_y1_output_mae: 21.4117 - val_y2_output_loss: 793.9233 - val_y2_output_mae: 23.6797
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3370.2505 - y1_output_loss: 1086.6293 - y1_output_mae: 26.6462 - y2_output_loss: 2309.4048 - y2_output_mae: 37.6655 - val_loss: 1393.5405 - val_y1_output_loss: 546.7115 - val_y1_output_mae: 17.6596 - val_y2_output_loss: 847.6342 - val_y2_output_mae: 23.8913
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3061.0090 - y1_output_loss: 956.8957 - y1_output_mae: 25.0982 - y2_output_loss: 2083.4587 - y2_output_mae: 36.2757 - val_loss: 2342.5405 - val_y1_output_loss: 283.8980 - val_y1_output_mae: 16.1009 - val_y2_output_loss: 2050.7585 - val_y2_output_mae: 38.8590
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3165.2427 - y1_output_loss: 1124.1632 - y1_output_mae: 25.9367 - y2_output_loss: 2022.7278 - y2_output_mae: 36.5877 - val_loss: 2766.2236 - val_y1_output_loss: 2225.0278 - val_y1_output_mae: 43.0791 - val_y2_output_loss: 539.0187 - val_y2_output_mae: 22.5690
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2439.0679 - y1_output_loss: 1329.5637 - y1_output_mae: 28.9843 - y2_output_loss: 1152.7107 - y2_output_mae: 27.6695 - val_loss: 2554.9280 - val_y1_output_loss: 1926.8887 - val_y1_output_mae: 39.5145 - val_y2_output_loss: 622.6508 - val_y2_output_mae: 22.0103
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3885.8523 - y1_output_loss: 1335.0116 - y1_output_mae: 29.7597 - y2_output_loss: 2517.3701 - y2_output_mae: 41.2790 - val_loss: 10104.0000 - val_y1_output_loss: 1186.7469 - val_y1_output_mae: 28.6394 - val_y2_output_loss: 8989.1387 - val_y2_output_mae: 89.6307
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5892.8193 - y1_output_loss: 2330.7715 - y1_output_mae: 39.1942 - y2_output_loss: 3363.0435 - y2_output_mae: 49.3218 - val_loss: 1950.8314 - val_y1_output_loss: 361.7874 - val_y1_output_mae: 18.0121 - val_y2_output_loss: 1607.6403 - val_y2_output_mae: 31.8783
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2593.8674 - y1_output_loss: 1692.8137 - y1_output_mae: 32.1801 - y2_output_loss: 890.1707 - y2_output_mae: 24.8523 - val_loss: 2236.8972 - val_y1_output_loss: 1433.1521 - val_y1_output_mae: 31.9903 - val_y2_output_loss: 812.7798 - val_y2_output_mae: 23.5078
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3848.8550 - y1_output_loss: 2557.7000 - y1_output_mae: 40.4942 - y2_output_loss: 1486.3802 - y2_output_mae: 29.6361 - val_loss: 5067.7070 - val_y1_output_loss: 419.1335 - val_y1_output_mae: 18.0960 - val_y2_output_loss: 4640.9272 - val_y2_output_mae: 63.1246
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8903.3262 - y1_output_loss: 4936.0322 - y1_output_mae: 57.6854 - y2_output_loss: 4015.4868 - y2_output_mae: 52.6609 - val_loss: 5129.0366 - val_y1_output_loss: 2935.1965 - val_y1_output_mae: 49.2576 - val_y2_output_loss: 2237.7668 - val_y2_output_mae: 40.3050
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 8035.8516 - y1_output_loss: 2941.2117 - y1_output_mae: 44.4062 - y2_output_loss: 4986.0088 - y2_output_mae: 59.1527 - val_loss: 16540.0215 - val_y1_output_loss: 1960.7249 - val_y1_output_mae: 39.2446 - val_y2_output_loss: 14583.7061 - val_y2_output_mae: 116.2843
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8208.5029 - y1_output_loss: 2516.6597 - y1_output_mae: 42.0908 - y2_output_loss: 5463.9028 - y2_output_mae: 62.4757 - val_loss: 1470.7257 - val_y1_output_loss: 904.6620 - val_y1_output_mae: 24.8232 - val_y2_output_loss: 561.7225 - val_y2_output_mae: 21.0614
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2315.1914 - y1_output_loss: 732.4285 - y1_output_mae: 22.6304 - y2_output_loss: 1530.1835 - y2_output_mae: 32.4036 - val_loss: 1263.5695 - val_y1_output_loss: 655.4894 - val_y1_output_mae: 20.3528 - val_y2_output_loss: 619.8371 - val_y2_output_mae: 22.6175
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2152.0325 - y1_output_loss: 1053.0166 - y1_output_mae: 24.3269 - y2_output_loss: 1222.1350 - y2_output_mae: 29.2633 - val_loss: 4919.0259 - val_y1_output_loss: 4117.4746 - val_y1_output_mae: 60.0345 - val_y2_output_loss: 795.9843 - val_y2_output_mae: 23.2005
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2955.1804 - y1_output_loss: 1403.8046 - y1_output_mae: 29.3851 - y2_output_loss: 1456.3445 - y2_output_mae: 30.9884 - val_loss: 1640.8514 - val_y1_output_loss: 853.3763 - val_y1_output_mae: 22.0064 - val_y2_output_loss: 804.1075 - val_y2_output_mae: 23.0156
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 8186.3184 - y1_output_loss: 2679.9600 - y1_output_mae: 42.6599 - y2_output_loss: 5280.9014 - y2_output_mae: 56.6523 - val_loss: 12585.5127 - val_y1_output_loss: 4211.4204 - val_y1_output_mae: 60.3225 - val_y2_output_loss: 8402.8672 - val_y2_output_mae: 87.3686
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 13271.8311 - y1_output_loss: 7769.7749 - y1_output_mae: 73.9757 - y2_output_loss: 5012.4648 - y2_output_mae: 59.4511 - val_loss: 5829.4868 - val_y1_output_loss: 4997.2847 - val_y1_output_mae: 66.2316 - val_y2_output_loss: 862.4401 - val_y2_output_mae: 23.9287
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 18158.4941 - y1_output_loss: 6220.7510 - y1_output_mae: 67.1047 - y2_output_loss: 11603.4121 - y2_output_mae: 90.5027 - val_loss: 45442.3555 - val_y1_output_loss: 5162.3696 - val_y1_output_mae: 67.9533 - val_y2_output_loss: 40350.7773 - val_y2_output_mae: 195.4890
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 22764.2793 - y1_output_loss: 5928.5410 - y1_output_mae: 62.9535 - y2_output_loss: 16039.3721 - y2_output_mae: 107.7169 - val_loss: 8050.5566 - val_y1_output_loss: 492.9872 - val_y1_output_mae: 19.3777 - val_y2_output_loss: 7615.5532 - val_y2_output_mae: 82.2272
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7767.7231 - y1_output_loss: 1162.7129 - y1_output_mae: 28.3715 - y2_output_loss: 6359.4873 - y2_output_mae: 66.3917 - val_loss: 3272.6008 - val_y1_output_loss: 2433.5334 - val_y1_output_mae: 44.7536 - val_y2_output_loss: 844.2308 - val_y2_output_mae: 22.8126
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4319.9678 - y1_output_loss: 2583.5247 - y1_output_mae: 43.5435 - y2_output_loss: 1623.5553 - y2_output_mae: 32.7549 - val_loss: 1037.9855 - val_y1_output_loss: 579.8454 - val_y1_output_mae: 19.5605 - val_y2_output_loss: 464.0118 - val_y2_output_mae: 20.3644
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3563.6013 - y1_output_loss: 2786.7163 - y1_output_mae: 43.8108 - y2_output_loss: 761.0308 - y2_output_mae: 22.9326 - val_loss: 1406.0248 - val_y1_output_loss: 844.1934 - val_y1_output_mae: 22.0272 - val_y2_output_loss: 568.1996 - val_y2_output_mae: 20.5802
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5837.7847 - y1_output_loss: 2393.5295 - y1_output_mae: 38.3689 - y2_output_loss: 3525.6921 - y2_output_mae: 45.7083 - val_loss: 15754.1426 - val_y1_output_loss: 5625.7524 - val_y1_output_mae: 71.2857 - val_y2_output_loss: 10195.9473 - val_y2_output_mae: 96.0561
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 26175.3867 - y1_output_loss: 3707.8828 - y1_output_mae: 43.5561 - y2_output_loss: 22496.9590 - y2_output_mae: 130.7579 - val_loss: 67380.7031 - val_y1_output_loss: 46348.0234 - val_y1_output_mae: 209.8443 - val_y2_output_loss: 21164.7910 - val_y2_output_mae: 141.0097
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 38208.9297 - y1_output_loss: 26071.9844 - y1_output_mae: 136.7124 - y2_output_loss: 11712.8232 - y2_output_mae: 86.0983 - val_loss: 8021.0542 - val_y1_output_loss: 6385.3306 - val_y1_output_mae: 76.2671 - val_y2_output_loss: 1632.3936 - val_y2_output_mae: 34.8923
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 20838.8457 - y1_output_loss: 17652.6406 - y1_output_mae: 112.3917 - y2_output_loss: 3043.7224 - y2_output_mae: 45.0034 - val_loss: 19459.7285 - val_y1_output_loss: 647.9651 - val_y1_output_mae: 20.9150 - val_y2_output_loss: 18917.5586 - val_y2_output_mae: 132.3997
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 42211.2578 - y1_output_loss: 6283.9570 - y1_output_mae: 62.5829 - y2_output_loss: 35051.1602 - y2_output_mae: 166.9641 - val_loss: 24654.9375 - val_y1_output_loss: 10024.1621 - val_y1_output_mae: 95.9009 - val_y2_output_loss: 14701.2324 - val_y2_output_mae: 117.0435
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 14139.0566 - y1_output_loss: 5290.6260 - y1_output_mae: 60.2012 - y2_output_loss: 8345.8926 - y2_output_mae: 77.1998 - val_loss: 4081.7927 - val_y1_output_loss: 2239.8367 - val_y1_output_mae: 42.4443 - val_y2_output_loss: 1854.2740 - val_y2_output_mae: 37.6897
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3056.1440 - y1_output_loss: 1632.4900 - y1_output_mae: 32.2544 - y2_output_loss: 1339.6577 - y2_output_mae: 29.6782 - val_loss: 836.4021 - val_y1_output_loss: 321.0338 - val_y1_output_mae: 16.9777 - val_y2_output_loss: 520.6909 - val_y2_output_mae: 20.9782
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2298.2361 - y1_output_loss: 1199.6345 - y1_output_mae: 24.8454 - y2_output_loss: 1410.3170 - y2_output_mae: 29.8044 - val_loss: 56911.4414 - val_y1_output_loss: 48173.4609 - val_y1_output_mae: 213.9941 - val_y2_output_loss: 8854.8477 - val_y2_output_mae: 90.0727
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 37984.1367 - y1_output_loss: 24329.0547 - y1_output_mae: 122.3091 - y2_output_loss: 12464.0293 - y2_output_mae: 96.0066 - val_loss: 1167.5255 - val_y1_output_loss: 441.0769 - val_y1_output_mae: 17.9730 - val_y2_output_loss: 727.2844 - val_y2_output_mae: 22.0938
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 17255.3535 - y1_output_loss: 1579.4061 - y1_output_mae: 31.2153 - y2_output_loss: 16233.0566 - y2_output_mae: 103.7457 - val_loss: 31596.2598 - val_y1_output_loss: 621.3420 - val_y1_output_mae: 19.0130 - val_y2_output_loss: 31143.9629 - val_y2_output_mae: 170.8797
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 23939.7852 - y1_output_loss: 2456.1985 - y1_output_mae: 39.4143 - y2_output_loss: 21241.1387 - y2_output_mae: 124.0833 - val_loss: 8823.5986 - val_y1_output_loss: 4690.9580 - val_y1_output_mae: 64.9544 - val_y2_output_loss: 4128.4648 - val_y2_output_mae: 59.9514
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 73808.2266 - y1_output_loss: 9516.8857 - y1_output_mae: 82.7342 - y2_output_loss: 65472.9492 - y2_output_mae: 208.2177 - val_loss: 62460.2734 - val_y1_output_loss: 24432.8164 - val_y1_output_mae: 151.5016 - val_y2_output_loss: 38342.1250 - val_y2_output_mae: 189.9475
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 76883.1641 - y1_output_loss: 26466.9570 - y1_output_mae: 132.6248 - y2_output_loss: 50544.9453 - y2_output_mae: 195.4007 - val_loss: 14466.4482 - val_y1_output_loss: 8388.7969 - val_y1_output_mae: 88.1507 - val_y2_output_loss: 6083.7617 - val_y2_output_mae: 73.9738
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 73075.5469 - y1_output_loss: 55113.9492 - y1_output_mae: 199.6183 - y2_output_loss: 15594.8223 - y2_output_mae: 103.1211 - val_loss: 48925.2422 - val_y1_output_loss: 46865.0703 - val_y1_output_mae: 211.1345 - val_y2_output_loss: 2169.0496 - val_y2_output_mae: 41.4983
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 19182.8730 - y1_output_loss: 13953.3799 - y1_output_mae: 96.3938 - y2_output_loss: 5031.8706 - y2_output_mae: 59.4376 - val_loss: 10029.9902 - val_y1_output_loss: 1790.5072 - val_y1_output_mae: 37.9971 - val_y2_output_loss: 8238.4482 - val_y2_output_mae: 86.8441
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 12619.5000 - y1_output_loss: 4283.0220 - y1_output_mae: 54.9730 - y2_output_loss: 8044.6533 - y2_output_mae: 78.2914 - val_loss: 8820.6689 - val_y1_output_loss: 2900.1411 - val_y1_output_mae: 50.1317 - val_y2_output_loss: 5916.7290 - val_y2_output_mae: 72.9051
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4838.6475 - y1_output_loss: 1681.0082 - y1_output_mae: 33.7293 - y2_output_loss: 3020.9294 - y2_output_mae: 45.8000 - val_loss: 2597.4927 - val_y1_output_loss: 1380.2247 - val_y1_output_mae: 32.7575 - val_y2_output_loss: 1209.9150 - val_y2_output_mae: 29.4358
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3105.4058 - y1_output_loss: 1095.5858 - y1_output_mae: 26.8744 - y2_output_loss: 1956.8457 - y2_output_mae: 36.6245 - val_loss: 745.1191 - val_y1_output_loss: 298.3268 - val_y1_output_mae: 16.0377 - val_y2_output_loss: 450.7519 - val_y2_output_mae: 20.0155
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1449.0536 - y1_output_loss: 696.2734 - y1_output_mae: 21.9868 - y2_output_loss: 742.9854 - y2_output_mae: 23.2134 - val_loss: 3521.9070 - val_y1_output_loss: 2043.6270 - val_y1_output_mae: 41.1955 - val_y2_output_loss: 1470.8933 - val_y2_output_mae: 33.1326
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5226.0322 - y1_output_loss: 2946.9470 - y1_output_mae: 45.5884 - y2_output_loss: 2353.3181 - y2_output_mae: 39.1833 - val_loss: 2601.2134 - val_y1_output_loss: 1597.6729 - val_y1_output_mae: 35.7031 - val_y2_output_loss: 1011.8635 - val_y2_output_mae: 24.2833
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 20548.1211 - y1_output_loss: 12498.1348 - y1_output_mae: 96.1133 - y2_output_loss: 7383.1743 - y2_output_mae: 72.9228 - val_loss: 16092.6172 - val_y1_output_loss: 12891.2354 - val_y1_output_mae: 109.4252 - val_y2_output_loss: 3299.1707 - val_y2_output_mae: 52.3266
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 52822.8047 - y1_output_loss: 10041.1045 - y1_output_mae: 81.4650 - y2_output_loss: 43910.0430 - y2_output_mae: 168.7740 - val_loss: 10944.6250 - val_y1_output_loss: 10607.3398 - val_y1_output_mae: 99.0263 - val_y2_output_loss: 399.3365 - val_y2_output_mae: 19.2808
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 76557.4375 - y1_output_loss: 4818.9619 - y1_output_mae: 53.9543 - y2_output_loss: 68786.7656 - y2_output_mae: 225.6883 - val_loss: 134393.7500 - val_y1_output_loss: 9443.0703 - val_y1_output_mae: 93.8093 - val_y2_output_loss: 125296.4844 - val_y2_output_mae: 345.7292
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 60770.0391 - y1_output_loss: 21268.4941 - y1_output_mae: 119.4727 - y2_output_loss: 38213.9727 - y2_output_mae: 157.2359 - val_loss: 20705.5039 - val_y1_output_loss: 604.0757 - val_y1_output_mae: 20.3583 - val_y2_output_loss: 20212.6035 - val_y2_output_mae: 137.2381
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 28456.8672 - y1_output_loss: 4342.0566 - y1_output_mae: 54.3067 - y2_output_loss: 23479.8555 - y2_output_mae: 127.8903 - val_loss: 3214.5957 - val_y1_output_loss: 322.7404 - val_y1_output_mae: 16.3498 - val_y2_output_loss: 2919.6638 - val_y2_output_mae: 48.8703
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 17125.1484 - y1_output_loss: 10487.5195 - y1_output_mae: 84.9158 - y2_output_loss: 6443.8877 - y2_output_mae: 63.2015 - val_loss: 13103.4023 - val_y1_output_loss: 9991.4824 - val_y1_output_mae: 96.5866 - val_y2_output_loss: 3120.5410 - val_y2_output_mae: 51.5218
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 14270.7129 - y1_output_loss: 8175.1846 - y1_output_mae: 75.3924 - y2_output_loss: 8409.5020 - y2_output_mae: 63.3533 - val_loss: 46761.6836 - val_y1_output_loss: 13794.7793 - val_y1_output_mae: 113.3740 - val_y2_output_loss: 33103.4766 - val_y2_output_mae: 177.1367
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 62916.8906 - y1_output_loss: 38454.7656 - y1_output_mae: 169.7075 - y2_output_loss: 24492.5586 - y2_output_mae: 130.1987 - val_loss: 8497.7959 - val_y1_output_loss: 4470.6177 - val_y1_output_mae: 63.0832 - val_y2_output_loss: 4053.1758 - val_y2_output_mae: 59.6328
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 24745.1953 - y1_output_loss: 17108.5039 - y1_output_mae: 102.6528 - y2_output_loss: 8029.8228 - y2_output_mae: 71.7570 - val_loss: 176495.1406 - val_y1_output_loss: 176044.9062 - val_y1_output_mae: 409.9681 - val_y2_output_loss: 994.5360 - val_y2_output_mae: 24.2366
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 115740.7812 - y1_output_loss: 103345.5312 - y1_output_mae: 272.7795 - y2_output_loss: 9160.3535 - y2_output_mae: 75.7271 - val_loss: 54042.3672 - val_y1_output_loss: 53860.7812 - val_y1_output_mae: 225.9438 - val_y2_output_loss: 420.3776 - val_y2_output_mae: 18.1653
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 81044.0391 - y1_output_loss: 37564.9180 - y1_output_mae: 155.2330 - y2_output_loss: 42402.5234 - y2_output_mae: 162.6556 - val_loss: 23213.7129 - val_y1_output_loss: 2861.7610 - val_y1_output_mae: 50.0725 - val_y2_output_loss: 20382.4238 - val_y2_output_mae: 138.6187
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 35561.7578 - y1_output_loss: 20798.0898 - y1_output_mae: 114.6144 - y2_output_loss: 14917.7393 - y2_output_mae: 102.7941 - val_loss: 84158.0547 - val_y1_output_loss: 40420.9453 - val_y1_output_mae: 196.0586 - val_y2_output_loss: 43930.2617 - val_y2_output_mae: 204.2891
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 49841.3242 - y1_output_loss: 20607.5859 - y1_output_mae: 118.9156 - y2_output_loss: 28922.6719 - y2_output_mae: 149.2463 - val_loss: 21937.6074 - val_y1_output_loss: 573.2010 - val_y1_output_mae: 19.8481 - val_y2_output_loss: 21395.9941 - val_y2_output_mae: 142.0445
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16281.8193 - y1_output_loss: 10178.8301 - y1_output_mae: 83.1860 - y2_output_loss: 5691.2783 - y2_output_mae: 59.0208 - val_loss: 31438.6016 - val_y1_output_loss: 7952.8335 - val_y1_output_mae: 85.4453 - val_y2_output_loss: 23571.1152 - val_y2_output_mae: 149.1922
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 13727.1387 - y1_output_loss: 8356.9639 - y1_output_mae: 76.1946 - y2_output_loss: 5018.6836 - y2_output_mae: 56.6514 - val_loss: 6713.6055 - val_y1_output_loss: 5092.6914 - val_y1_output_mae: 67.6920 - val_y2_output_loss: 1648.7946 - val_y2_output_mae: 35.8064
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8236.3887 - y1_output_loss: 1873.8929 - y1_output_mae: 34.0465 - y2_output_loss: 6502.5303 - y2_output_mae: 65.3712 - val_loss: 3450.9099 - val_y1_output_loss: 681.9727 - val_y1_output_mae: 22.0498 - val_y2_output_loss: 2791.0188 - val_y2_output_mae: 47.8093
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2751.1042 - y1_output_loss: 1269.3680 - y1_output_mae: 29.8956 - y2_output_loss: 1459.4628 - y2_output_mae: 30.1168 - val_loss: 2604.6660 - val_y1_output_loss: 790.9209 - val_y1_output_mae: 22.3929 - val_y2_output_loss: 1838.7844 - val_y2_output_mae: 37.2199
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 13193.7422 - y1_output_loss: 2028.1943 - y1_output_mae: 37.0520 - y2_output_loss: 10754.3867 - y2_output_mae: 84.1072 - val_loss: 27372.6387 - val_y1_output_loss: 4625.8506 - val_y1_output_mae: 64.8595 - val_y2_output_loss: 22872.7168 - val_y2_output_mae: 146.2890
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 84475.8203 - y1_output_loss: 4584.2690 - y1_output_mae: 56.9841 - y2_output_loss: 80464.2812 - y2_output_mae: 238.7737 - val_loss: 455858.2812 - val_y1_output_loss: 534.5764 - val_y1_output_mae: 17.5141 - val_y2_output_loss: 457136.3438 - val_y2_output_mae: 660.1028
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 92063.3516 - y1_output_loss: 2564.3755 - y1_output_mae: 39.5891 - y2_output_loss: 87755.8672 - y2_output_mae: 250.6430 - val_loss: 29943.3379 - val_y1_output_loss: 27077.4473 - val_y1_output_mae: 159.8228 - val_y2_output_loss: 3020.0815 - val_y2_output_mae: 50.0854
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 17909.4648 - y1_output_loss: 5189.1162 - y1_output_mae: 56.2341 - y2_output_loss: 12593.4160 - y2_output_mae: 90.8802 - val_loss: 9620.5293 - val_y1_output_loss: 8998.4248 - val_y1_output_mae: 91.6676 - val_y2_output_loss: 641.7895 - val_y2_output_mae: 19.9313
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 15774.0029 - y1_output_loss: 5353.6162 - y1_output_mae: 55.2437 - y2_output_loss: 12012.8340 - y2_output_mae: 88.0291 - val_loss: 100617.3906 - val_y1_output_loss: 73676.7969 - val_y1_output_mae: 265.1146 - val_y2_output_loss: 27287.5430 - val_y2_output_mae: 160.0579
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 46218.3828 - y1_output_loss: 30728.3027 - y1_output_mae: 151.6817 - y2_output_loss: 14937.6094 - y2_output_mae: 100.0451 - val_loss: 5735.4473 - val_y1_output_loss: 4992.9307 - val_y1_output_mae: 67.5784 - val_y2_output_loss: 754.5731 - val_y2_output_mae: 20.7299
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 47405.6914 - y1_output_loss: 16495.6074 - y1_output_mae: 103.6095 - y2_output_loss: 29642.0879 - y2_output_mae: 146.7595 - val_loss: 15632.8994 - val_y1_output_loss: 5163.3232 - val_y1_output_mae: 68.2930 - val_y2_output_loss: 10510.7285 - val_y2_output_mae: 98.8630
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 59740.9297 - y1_output_loss: 47553.2422 - y1_output_mae: 186.6653 - y2_output_loss: 11435.7715 - y2_output_mae: 88.2290 - val_loss: 18194.3379 - val_y1_output_loss: 13839.7871 - val_y1_output_mae: 114.2059 - val_y2_output_loss: 4377.4248 - val_y2_output_mae: 62.3670
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 58891.8164 - y1_output_loss: 58222.1484 - y1_output_mae: 199.2273 - y2_output_loss: 2041.5150 - y2_output_mae: 36.3948 - val_loss: 3891.2832 - val_y1_output_loss: 2397.0886 - val_y1_output_mae: 45.1010 - val_y2_output_loss: 1527.1769 - val_y2_output_mae: 33.1703
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 56009.0820 - y1_output_loss: 58042.3672 - y1_output_mae: 194.3411 - y2_output_loss: 982.2933 - y2_output_mae: 25.7044 - val_loss: 15194.4707 - val_y1_output_loss: 13970.4473 - val_y1_output_mae: 114.7521 - val_y2_output_loss: 1262.8909 - val_y2_output_mae: 29.2366
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 76863.6250 - y1_output_loss: 74280.2812 - y1_output_mae: 226.5923 - y2_output_loss: 909.8732 - y2_output_mae: 24.0311 - val_loss: 77123.6719 - val_y1_output_loss: 72929.1641 - val_y1_output_mae: 263.7357 - val_y2_output_loss: 4396.1392 - val_y2_output_mae: 62.5381
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 65198.2461 - y1_output_loss: 37261.6328 - y1_output_mae: 159.6304 - y2_output_loss: 26645.0312 - y2_output_mae: 140.3233 - val_loss: 21467.1738 - val_y1_output_loss: 14774.5488 - val_y1_output_mae: 117.6029 - val_y2_output_loss: 6769.7915 - val_y2_output_mae: 78.6529
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 43305.0078 - y1_output_loss: 22694.5840 - y1_output_mae: 127.7720 - y2_output_loss: 19310.9277 - y2_output_mae: 107.8489 - val_loss: 11206.9209 - val_y1_output_loss: 8808.3105 - val_y1_output_mae: 90.7343 - val_y2_output_loss: 2407.6196 - val_y2_output_mae: 44.7279
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 37667.4961 - y1_output_loss: 10827.7246 - y1_output_mae: 79.9513 - y2_output_loss: 25571.5449 - y2_output_mae: 135.5835 - val_loss: 6310.9912 - val_y1_output_loss: 330.5771 - val_y1_output_mae: 15.3547 - val_y2_output_loss: 6025.9521 - val_y2_output_mae: 73.3122
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 33478.4688 - y1_output_loss: 2128.1206 - y1_output_mae: 36.7852 - y2_output_loss: 30256.8945 - y2_output_mae: 145.4197 - val_loss: 114699.4062 - val_y1_output_loss: 6309.6943 - val_y1_output_mae: 75.9516 - val_y2_output_loss: 108903.4766 - val_y2_output_mae: 321.6944
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 67441.5312 - y1_output_loss: 3261.0840 - y1_output_mae: 48.0969 - y2_output_loss: 61674.4062 - y2_output_mae: 214.1702 - val_loss: 16343.5605 - val_y1_output_loss: 1298.4221 - val_y1_output_mae: 31.6876 - val_y2_output_loss: 15143.5605 - val_y2_output_mae: 118.5592
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 13690.1758 - y1_output_loss: 1328.4622 - y1_output_mae: 29.3087 - y2_output_loss: 13215.4629 - y2_output_mae: 90.8726 - val_loss: 1172.2120 - val_y1_output_loss: 632.9193 - val_y1_output_mae: 19.6159 - val_y2_output_loss: 551.5444 - val_y2_output_mae: 19.2343
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 43526.8867 - y1_output_loss: 1438.6405 - y1_output_mae: 31.6003 - y2_output_loss: 43606.2031 - y2_output_mae: 175.5980 - val_loss: 3396.6472 - val_y1_output_loss: 424.9654 - val_y1_output_mae: 15.8823 - val_y2_output_loss: 2972.4248 - val_y2_output_mae: 50.4886
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 102877.5625 - y1_output_loss: 1562.9133 - y1_output_mae: 28.4351 - y2_output_loss: 99068.2734 - y2_output_mae: 273.3341 - val_loss: 1014.5340 - val_y1_output_loss: 687.0386 - val_y1_output_mae: 20.7796 - val_y2_output_loss: 335.3867 - val_y2_output_mae: 17.4835
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 89510.8125 - y1_output_loss: 18008.4453 - y1_output_mae: 110.4480 - y2_output_loss: 68736.1094 - y2_output_mae: 221.1239 - val_loss: 31124.7598 - val_y1_output_loss: 4108.9868 - val_y1_output_mae: 61.1522 - val_y2_output_loss: 27160.2930 - val_y2_output_mae: 159.7541
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 108532.2266 - y1_output_loss: 89526.3984 - y1_output_mae: 229.5833 - y2_output_loss: 18155.8945 - y2_output_mae: 106.5742 - val_loss: 89075.2812 - val_y1_output_loss: 37990.5547 - val_y1_output_mae: 190.2119 - val_y2_output_loss: 51307.1367 - val_y2_output_mae: 221.0530
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 65045.9688 - y1_output_loss: 41590.2305 - y1_output_mae: 173.4344 - y2_output_loss: 22309.7070 - y2_output_mae: 122.9164 - val_loss: 52374.3203 - val_y1_output_loss: 45617.2891 - val_y1_output_mae: 208.0431 - val_y2_output_loss: 7008.3320 - val_y2_output_mae: 79.5379
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 33249.3477 - y1_output_loss: 24458.4902 - y1_output_mae: 134.0538 - y2_output_loss: 8251.2949 - y2_output_mae: 75.3442 - val_loss: 35660.6094 - val_y1_output_loss: 17393.5957 - val_y1_output_mae: 128.3389 - val_y2_output_loss: 18334.9844 - val_y2_output_mae: 131.5326
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 36147.3828 - y1_output_loss: 15992.6895 - y1_output_mae: 104.8854 - y2_output_loss: 18950.2383 - y2_output_mae: 119.4250 - val_loss: 2416.7217 - val_y1_output_loss: 358.1862 - val_y1_output_mae: 15.2164 - val_y2_output_loss: 2081.0347 - val_y2_output_mae: 40.5746
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 36718.1641 - y1_output_loss: 3045.8491 - y1_output_mae: 43.6433 - y2_output_loss: 33092.3555 - y2_output_mae: 153.2483 - val_loss: 34865.0664 - val_y1_output_loss: 4920.1323 - val_y1_output_mae: 67.2581 - val_y2_output_loss: 30011.9434 - val_y2_output_mae: 168.7829
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 63114.3242 - y1_output_loss: 3334.6587 - y1_output_mae: 48.9172 - y2_output_loss: 57301.1016 - y2_output_mae: 208.3382 - val_loss: 28518.9219 - val_y1_output_loss: 5573.3403 - val_y1_output_mae: 71.2947 - val_y2_output_loss: 23102.4805 - val_y2_output_mae: 147.2220
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 33288.4805 - y1_output_loss: 6632.5693 - y1_output_mae: 69.6341 - y2_output_loss: 26145.8105 - y2_output_mae: 126.1091 - val_loss: 12712.2666 - val_y1_output_loss: 2641.5776 - val_y1_output_mae: 47.8763 - val_y2_output_loss: 10152.4121 - val_y2_output_mae: 96.5851
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 73908.1641 - y1_output_loss: 19188.6836 - y1_output_mae: 109.5453 - y2_output_loss: 54839.2500 - y2_output_mae: 205.1636 - val_loss: 15947.4639 - val_y1_output_loss: 5137.6133 - val_y1_output_mae: 68.8110 - val_y2_output_loss: 10827.3154 - val_y2_output_mae: 100.5403
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 201492.0469 - y1_output_loss: 190834.2344 - y1_output_mae: 373.5625 - y2_output_loss: 5516.0557 - y2_output_mae: 56.8486 - val_loss: 8283.6123 - val_y1_output_loss: 6279.8071 - val_y1_output_mae: 75.8783 - val_y2_output_loss: 2059.4753 - val_y2_output_mae: 40.4122
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 96403.8906 - y1_output_loss: 87237.2578 - y1_output_mae: 244.4419 - y2_output_loss: 7306.4741 - y2_output_mae: 71.8395 - val_loss: 1188.1293 - val_y1_output_loss: 226.9426 - val_y1_output_mae: 13.6286 - val_y2_output_loss: 958.3004 - val_y2_output_mae: 26.3497
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 39189.3320 - y1_output_loss: 28788.1719 - y1_output_mae: 140.7874 - y2_output_loss: 8978.3691 - y2_output_mae: 76.9437 - val_loss: 24862.5078 - val_y1_output_loss: 5740.1030 - val_y1_output_mae: 72.4163 - val_y2_output_loss: 19189.0586 - val_y2_output_mae: 134.5872
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 44261.3438 - y1_output_loss: 8047.0166 - y1_output_mae: 71.9025 - y2_output_loss: 34728.1445 - y2_output_mae: 157.9074 - val_loss: 3420.1875 - val_y1_output_loss: 2537.0913 - val_y1_output_mae: 46.9054 - val_y2_output_loss: 911.0209 - val_y2_output_mae: 23.6315
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 38735.8359 - y1_output_loss: 11425.9072 - y1_output_mae: 91.2462 - y2_output_loss: 28804.4316 - y2_output_mae: 135.5953 - val_loss: 25926.1191 - val_y1_output_loss: 2437.0059 - val_y1_output_mae: 45.8727 - val_y2_output_loss: 23632.0430 - val_y2_output_mae: 148.8996
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 47180.7031 - y1_output_loss: 11673.0957 - y1_output_mae: 90.7801 - y2_output_loss: 34817.6328 - y2_output_mae: 155.8558 - val_loss: 43688.3359 - val_y1_output_loss: 12067.7061 - val_y1_output_mae: 106.6325 - val_y2_output_loss: 31805.2070 - val_y2_output_mae: 173.1037
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 34793.2070 - y1_output_loss: 8888.7129 - y1_output_mae: 79.3220 - y2_output_loss: 24873.9766 - y2_output_mae: 135.2852 - val_loss: 53187.4531 - val_y1_output_loss: 1290.3303 - val_y1_output_mae: 32.3639 - val_y2_output_loss: 52022.5547 - val_y2_output_mae: 222.5291
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 104937.9141 - y1_output_loss: 29999.9160 - y1_output_mae: 140.9995 - y2_output_loss: 73283.2656 - y2_output_mae: 209.9939 - val_loss: 236827.6406 - val_y1_output_loss: 79939.1016 - val_y1_output_mae: 275.7117 - val_y2_output_loss: 157686.8906 - val_y2_output_mae: 387.9850
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 81247.8594 - y1_output_loss: 28198.4336 - y1_output_mae: 144.2532 - y2_output_loss: 52498.1133 - y2_output_mae: 180.9237 - val_loss: 94669.5938 - val_y1_output_loss: 210.0240 - val_y1_output_mae: 13.5917 - val_y2_output_loss: 94882.8594 - val_y2_output_mae: 300.2051
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 83968.6094 - y1_output_loss: 15845.7451 - y1_output_mae: 107.2149 - y2_output_loss: 65174.8867 - y2_output_mae: 217.8279 - val_loss: 15740.2422 - val_y1_output_loss: 13924.1953 - val_y1_output_mae: 114.2277 - val_y2_output_loss: 1884.0051 - val_y2_output_mae: 39.1897
# Epoch 107/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 28228.9707 - y1_output_loss: 22335.2402 - y1_output_mae: 109.9197 - y2_output_loss: 7312.2100 - y2_output_mae: 70.3597 - val_loss: 9177.8809 - val_y1_output_loss: 1647.0300 - val_y1_output_mae: 36.9273 - val_y2_output_loss: 7548.6455 - val_y2_output_mae: 83.4951
# Epoch 108/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 75123.4219 - y1_output_loss: 29408.4941 - y1_output_mae: 142.2489 - y2_output_loss: 49050.0664 - y2_output_mae: 175.5995 - val_loss: 118938.4922 - val_y1_output_loss: 5098.5127 - val_y1_output_mae: 68.5789 - val_y2_output_loss: 114168.7891 - val_y2_output_mae: 330.0820
# Epoch 109/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 65011.1211 - y1_output_loss: 10365.2441 - y1_output_mae: 84.2965 - y2_output_loss: 55151.6367 - y2_output_mae: 196.4385 - val_loss: 134871.9375 - val_y1_output_loss: 813.0071 - val_y1_output_mae: 23.8781 - val_y2_output_loss: 134647.4688 - val_y2_output_mae: 357.8941
# Epoch 110/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 89487.1172 - y1_output_loss: 27721.4590 - y1_output_mae: 114.2234 - y2_output_loss: 69868.4531 - y2_output_mae: 214.0582 - val_loss: 828335.5625 - val_y1_output_loss: 422948.9062 - val_y1_output_mae: 635.2153 - val_y2_output_loss: 408672.5312 - val_y2_output_mae: 624.2186
# Epoch 111/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 403907.4688 - y1_output_loss: 214963.5312 - y1_output_mae: 384.5343 - y2_output_loss: 193824.9219 - y2_output_mae: 377.6003 - val_loss: 59160.2969 - val_y1_output_loss: 55810.3203 - val_y1_output_mae: 230.2836 - val_y2_output_loss: 3591.0298 - val_y2_output_mae: 56.3384
# Epoch 112/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 391934.3438 - y1_output_loss: 278626.5938 - y1_output_mae: 451.7557 - y2_output_loss: 98727.8281 - y2_output_mae: 249.7757 - val_loss: 201303.2031 - val_y1_output_loss: 193292.5312 - val_y1_output_mae: 429.6650 - val_y2_output_loss: 8631.6904 - val_y2_output_mae: 89.4974
# Epoch 113/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 193076.5469 - y1_output_loss: 177406.1719 - y1_output_mae: 363.9031 - y2_output_loss: 10160.8623 - y2_output_mae: 81.1661 - val_loss: 236957.7188 - val_y1_output_loss: 232055.1250 - val_y1_output_mae: 470.8238 - val_y2_output_loss: 5651.6885 - val_y2_output_mae: 71.7924
# Epoch 114/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 107190.8047 - y1_output_loss: 102519.5703 - y1_output_mae: 262.6940 - y2_output_loss: 4732.0259 - y2_output_mae: 58.2826 - val_loss: 1266.3173 - val_y1_output_loss: 462.2426 - val_y1_output_mae: 18.0100 - val_y2_output_loss: 811.9922 - val_y2_output_mae: 22.1143
# Epoch 115/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 47151.5781 - y1_output_loss: 44012.1328 - y1_output_mae: 171.8702 - y2_output_loss: 3845.1797 - y2_output_mae: 50.7822 - val_loss: 130407.4141 - val_y1_output_loss: 130523.8984 - val_y1_output_mae: 352.6429 - val_y2_output_loss: 415.6849 - val_y2_output_mae: 17.2698
# Epoch 116/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 117874.2812 - y1_output_loss: 118561.0625 - y1_output_mae: 282.6662 - y2_output_loss: 1876.7836 - y2_output_mae: 32.4897 - val_loss: 80486.7344 - val_y1_output_loss: 74540.9766 - val_y1_output_mae: 266.2608 - val_y2_output_loss: 6305.8384 - val_y2_output_mae: 75.4670
# Epoch 117/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 65646.2031 - y1_output_loss: 61069.6992 - y1_output_mae: 214.4220 - y2_output_loss: 3219.3782 - y2_output_mae: 42.3936 - val_loss: 100625.1719 - val_y1_output_loss: 30969.5039 - val_y1_output_mae: 171.6145 - val_y2_output_loss: 69917.4375 - val_y2_output_mae: 258.1372
# Epoch 118/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 63546.3984 - y1_output_loss: 15155.9502 - y1_output_mae: 95.0429 - y2_output_loss: 47410.5703 - y2_output_mae: 191.4861 - val_loss: 22464.8984 - val_y1_output_loss: 619.6346 - val_y1_output_mae: 21.5277 - val_y2_output_loss: 21883.8906 - val_y2_output_mae: 143.8456
# Epoch 119/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15243.0117 - y1_output_loss: 2048.4746 - y1_output_mae: 35.9559 - y2_output_loss: 13083.8838 - y2_output_mae: 93.1592 - val_loss: 13735.3213 - val_y1_output_loss: 1481.1379 - val_y1_output_mae: 34.8252 - val_y2_output_loss: 12281.8301 - val_y2_output_mae: 107.2755
# Epoch 120/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 11098.4727 - y1_output_loss: 1071.3557 - y1_output_mae: 26.3593 - y2_output_loss: 9721.3691 - y2_output_mae: 85.1563 - val_loss: 1552.9711 - val_y1_output_loss: 1259.6062 - val_y1_output_mae: 32.0642 - val_y2_output_loss: 293.7753 - val_y2_output_mae: 16.3774
# Epoch 121/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4386.2651 - y1_output_loss: 739.4083 - y1_output_mae: 22.4474 - y2_output_loss: 4482.8232 - y2_output_mae: 46.0183 - val_loss: 113641.2188 - val_y1_output_loss: 317.7780 - val_y1_output_mae: 14.2378 - val_y2_output_loss: 113820.8281 - val_y2_output_mae: 328.9652
# Epoch 122/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 205891.2500 - y1_output_loss: 481.6449 - y1_output_mae: 18.0665 - y2_output_loss: 212680.9219 - y2_output_mae: 400.6325 - val_loss: 5064.1289 - val_y1_output_loss: 458.6837 - val_y1_output_mae: 18.0421 - val_y2_output_loss: 4603.8989 - val_y2_output_mae: 64.4148
# Epoch 123/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 155059.7969 - y1_output_loss: 1438.1160 - y1_output_mae: 31.6106 - y2_output_loss: 163635.3906 - y2_output_mae: 326.9762 - val_loss: 900819.2500 - val_y1_output_loss: 4783.0430 - val_y1_output_mae: 66.0140 - val_y2_output_loss: 899052.0000 - val_y2_output_mae: 926.7466
# Epoch 124/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 209162.8125 - y1_output_loss: 1589.1648 - y1_output_mae: 33.5398 - y2_output_loss: 202680.5469 - y2_output_mae: 371.4445 - val_loss: 280672.3750 - val_y1_output_loss: 329.7629 - val_y1_output_mae: 14.2509 - val_y2_output_loss: 281225.4375 - val_y2_output_mae: 518.3250
# Epoch 125/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 233895.6406 - y1_output_loss: 1028.2081 - y1_output_mae: 25.7365 - y2_output_loss: 225956.1719 - y2_output_mae: 387.1930 - val_loss: 12283.5449 - val_y1_output_loss: 2245.2424 - val_y1_output_mae: 44.0935 - val_y2_output_loss: 10117.0947 - val_y2_output_mae: 96.5816
# Epoch 126/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 44968.2773 - y1_output_loss: 1104.4054 - y1_output_mae: 27.1651 - y2_output_loss: 45447.7656 - y2_output_mae: 167.7505 - val_loss: 126982.5078 - val_y1_output_loss: 1173.9749 - val_y1_output_mae: 30.8507 - val_y2_output_loss: 126171.6250 - val_y2_output_mae: 347.0796
# Epoch 127/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 59645.8359 - y1_output_loss: 720.8434 - y1_output_mae: 21.3997 - y2_output_loss: 57090.4492 - y2_output_mae: 208.5908 - val_loss: 57051.2969 - val_y1_output_loss: 5635.1719 - val_y1_output_mae: 72.3055 - val_y2_output_loss: 51667.9883 - val_y2_output_mae: 221.3267
# Epoch 128/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 27307.8438 - y1_output_loss: 1731.5638 - y1_output_mae: 33.8287 - y2_output_loss: 25001.8398 - y2_output_mae: 138.4117 - val_loss: 85442.5312 - val_y1_output_loss: 536.6229 - val_y1_output_mae: 19.8505 - val_y2_output_loss: 85137.7266 - val_y2_output_mae: 285.0416
# Epoch 129/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 32756.7402 - y1_output_loss: 4724.0884 - y1_output_mae: 56.0661 - y2_output_loss: 28209.7383 - y2_output_mae: 140.4669 - val_loss: 17167.2070 - val_y1_output_loss: 12824.1426 - val_y1_output_mae: 109.7044 - val_y2_output_loss: 4441.6270 - val_y2_output_mae: 62.7351
# Epoch 130/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 31311.3281 - y1_output_loss: 13128.3047 - y1_output_mae: 96.5913 - y2_output_loss: 18072.5078 - y2_output_mae: 112.8465 - val_loss: 1646.0073 - val_y1_output_loss: 432.9063 - val_y1_output_mae: 15.8820 - val_y2_output_loss: 1214.3923 - val_y2_output_mae: 30.6210
# Epoch 131/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15493.7344 - y1_output_loss: 2638.5786 - y1_output_mae: 41.7183 - y2_output_loss: 12556.8643 - y2_output_mae: 91.8636 - val_loss: 3810.5496 - val_y1_output_loss: 3085.4968 - val_y1_output_mae: 52.8035 - val_y2_output_loss: 724.6467 - val_y2_output_mae: 22.6443
# Epoch 132/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 14405.6338 - y1_output_loss: 13798.4951 - y1_output_mae: 79.2508 - y2_output_loss: 4803.8408 - y2_output_mae: 54.0243 - val_loss: 43328.9141 - val_y1_output_loss: 42436.0391 - val_y1_output_mae: 200.7622 - val_y2_output_loss: 1092.9789 - val_y2_output_mae: 27.5813
# Epoch 133/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 126597.1484 - y1_output_loss: 117944.6250 - y1_output_mae: 260.8913 - y2_output_loss: 14396.1660 - y2_output_mae: 101.5674 - val_loss: 1731656.2500 - val_y1_output_loss: 1729746.7500 - val_y1_output_mae: 1285.7701 - val_y2_output_loss: 7921.2236 - val_y2_output_mae: 85.7023
# Epoch 134/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 961802.8125 - y1_output_loss: 953830.8750 - y1_output_mae: 828.1316 - y2_output_loss: 10783.3574 - y2_output_mae: 83.5382 - val_loss: 762296.7500 - val_y1_output_loss: 753852.1250 - val_y1_output_mae: 848.5013 - val_y2_output_loss: 11373.9111 - val_y2_output_mae: 102.7194
# Epoch 135/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 571717.3750 - y1_output_loss: 556183.8750 - y1_output_mae: 650.7269 - y2_output_loss: 4022.4849 - y2_output_mae: 51.6704 - val_loss: 698429.6250 - val_y1_output_loss: 679033.8750 - val_y1_output_mae: 805.2065 - val_y2_output_loss: 22023.9473 - val_y2_output_mae: 144.4073
# Epoch 136/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 233785.3281 - y1_output_loss: 218772.6719 - y1_output_mae: 377.3871 - y2_output_loss: 7006.5210 - y2_output_mae: 69.3283 - val_loss: 7436.3594 - val_y1_output_loss: 3386.1262 - val_y1_output_mae: 55.0478 - val_y2_output_loss: 4102.9580 - val_y2_output_mae: 60.1502
# Epoch 137/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 30655.5020 - y1_output_loss: 29159.1973 - y1_output_mae: 135.6280 - y2_output_loss: 2167.2310 - y2_output_mae: 38.3029 - val_loss: 22863.0664 - val_y1_output_loss: 19386.7930 - val_y1_output_mae: 135.5920 - val_y2_output_loss: 3520.8992 - val_y2_output_mae: 55.9191
# Epoch 138/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 11452.3818 - y1_output_loss: 8784.6660 - y1_output_mae: 72.3926 - y2_output_loss: 2590.9285 - y2_output_mae: 39.0893 - val_loss: 9996.1973 - val_y1_output_loss: 995.7239 - val_y1_output_mae: 27.6319 - val_y2_output_loss: 9018.6025 - val_y2_output_mae: 91.6411
# Epoch 139/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5916.8418 - y1_output_loss: 1866.2972 - y1_output_mae: 34.9063 - y2_output_loss: 3881.9297 - y2_output_mae: 52.3918 - val_loss: 1094.5105 - val_y1_output_loss: 635.3149 - val_y1_output_mae: 20.5282 - val_y2_output_loss: 463.8351 - val_y2_output_mae: 17.7952
# Epoch 140/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5333.6270 - y1_output_loss: 607.4194 - y1_output_mae: 20.0263 - y2_output_loss: 4554.6191 - y2_output_mae: 55.4458 - val_loss: 8570.6562 - val_y1_output_loss: 1857.2369 - val_y1_output_mae: 40.1202 - val_y2_output_loss: 6717.8218 - val_y2_output_mae: 78.6999
# Epoch 141/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4876.0283 - y1_output_loss: 1486.7848 - y1_output_mae: 33.3520 - y2_output_loss: 3277.2083 - y2_output_mae: 42.8356 - val_loss: 8302.7002 - val_y1_output_loss: 3522.8198 - val_y1_output_mae: 56.2850 - val_y2_output_loss: 4803.3701 - val_y2_output_mae: 66.0351
# Epoch 142/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 36960.9766 - y1_output_loss: 1300.4666 - y1_output_mae: 30.8117 - y2_output_loss: 34237.5547 - y2_output_mae: 163.6350 - val_loss: 11357.8799 - val_y1_output_loss: 2698.0645 - val_y1_output_mae: 49.1662 - val_y2_output_loss: 8669.7949 - val_y2_output_mae: 89.8002
# Epoch 143/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 107130.2969 - y1_output_loss: 1490.1830 - y1_output_mae: 32.8433 - y2_output_loss: 103955.0078 - y2_output_mae: 279.0230 - val_loss: 54582.9336 - val_y1_output_loss: 1742.1064 - val_y1_output_mae: 38.3999 - val_y2_output_loss: 52987.0234 - val_y2_output_mae: 224.6485
# Epoch 144/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 22461.2500 - y1_output_loss: 1563.1206 - y1_output_mae: 33.3161 - y2_output_loss: 20653.5977 - y2_output_mae: 118.2316 - val_loss: 19740.1211 - val_y1_output_loss: 211.1404 - val_y1_output_mae: 12.8458 - val_y2_output_loss: 19565.2969 - val_y2_output_mae: 136.0062
# Epoch 145/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 22951.6523 - y1_output_loss: 768.0542 - y1_output_mae: 22.4941 - y2_output_loss: 21764.1055 - y2_output_mae: 116.7300 - val_loss: 56193.0391 - val_y1_output_loss: 704.1499 - val_y1_output_mae: 23.3595 - val_y2_output_loss: 55746.7266 - val_y2_output_mae: 229.9581
# Epoch 146/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 459531.8750 - y1_output_loss: 436.0218 - y1_output_mae: 17.1454 - y2_output_loss: 451136.1562 - y2_output_mae: 599.1794 - val_loss: 709.8292 - val_y1_output_loss: 429.0040 - val_y1_output_mae: 17.4761 - val_y2_output_loss: 282.4156 - val_y2_output_mae: 15.7485
# Epoch 147/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 279566.0312 - y1_output_loss: 472.5512 - y1_output_mae: 17.7658 - y2_output_loss: 272524.9062 - y2_output_mae: 426.1810 - val_loss: 82854.1562 - val_y1_output_loss: 292.2538 - val_y1_output_mae: 14.3957 - val_y2_output_loss: 82788.3281 - val_y2_output_mae: 281.0303
# Epoch 148/200
# ...
# Epoch 152/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6453.7012 - y1_output_loss: 511.3242 - y1_output_mae: 18.4306 - y2_output_loss: 6554.1392 - y2_output_mae: 60.2219 - val_loss: 64767.2539 - val_y1_output_loss: 192.8256 - val_y1_output_mae: 12.7200 - val_y2_output_loss: 64747.2188 - val_y2_output_mae: 248.4326
# Epoch 153/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16214.7881 - y1_output_loss: 270.4846 - y1_output_mae: 13.6967 - y2_output_loss: 15695.4785 - y2_output_mae: 102.3227 - val_loss: 699.6114 - val_y1_output_loss: 366.0375 - val_y1_output_mae: 14.5523 - val_y2_output_loss: 341.0829 - val_y2_output_mae: 16.2443
# Epoch 154/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6467.7563 - y1_output_loss: 354.6671 - y1_output_mae: 15.5700 - y2_output_loss: 5889.2407 - y2_output_mae: 66.2065 - val_loss: 7088.7280 - val_y1_output_loss: 187.0050 - val_y1_output_mae: 12.3757 - val_y2_output_loss: 6947.3853 - val_y2_output_mae: 79.7039
# Epoch 155/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3639.7451 - y1_output_loss: 346.7239 - y1_output_mae: 15.5464 - y2_output_loss: 3286.5435 - y2_output_mae: 47.1980 - val_loss: 15638.6885 - val_y1_output_loss: 755.7507 - val_y1_output_mae: 23.3302 - val_y2_output_loss: 14973.7910 - val_y2_output_mae: 118.3378
# Epoch 156/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9222.1875 - y1_output_loss: 3050.3335 - y1_output_mae: 44.0855 - y2_output_loss: 6223.1841 - y2_output_mae: 65.6260 - val_loss: 626.3865 - val_y1_output_loss: 192.8169 - val_y1_output_mae: 12.4554 - val_y2_output_loss: 438.9399 - val_y2_output_mae: 16.7087
# Epoch 157/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4936.5967 - y1_output_loss: 1347.5229 - y1_output_mae: 30.7649 - y2_output_loss: 3415.0684 - y2_output_mae: 47.8584 - val_loss: 526.3738 - val_y1_output_loss: 259.8805 - val_y1_output_mae: 13.7258 - val_y2_output_loss: 267.9941 - val_y2_output_mae: 15.5581
# Epoch 158/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2930.7617 - y1_output_loss: 615.9021 - y1_output_mae: 19.8266 - y2_output_loss: 2366.7632 - y2_output_mae: 39.4362 - val_loss: 2638.8677 - val_y1_output_loss: 1008.0668 - val_y1_output_mae: 28.0340 - val_y2_output_loss: 1636.5515 - val_y2_output_mae: 36.5868
# Epoch 159/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3068.8220 - y1_output_loss: 638.3743 - y1_output_mae: 18.8145 - y2_output_loss: 2408.1216 - y2_output_mae: 41.1474 - val_loss: 4758.4268 - val_y1_output_loss: 1596.9010 - val_y1_output_mae: 36.9921 - val_y2_output_loss: 3186.1321 - val_y2_output_mae: 52.6619
# Epoch 160/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4120.7124 - y1_output_loss: 3181.5591 - y1_output_mae: 44.3459 - y2_output_loss: 904.4707 - y2_output_mae: 24.0187 - val_loss: 4533.6294 - val_y1_output_loss: 4279.2568 - val_y1_output_mae: 62.7586 - val_y2_output_loss: 260.1718 - val_y2_output_mae: 15.1014
# Epoch 161/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6322.3823 - y1_output_loss: 5770.4209 - y1_output_mae: 64.9209 - y2_output_loss: 403.6028 - y2_output_mae: 16.7601 - val_loss: 15461.4775 - val_y1_output_loss: 15280.6543 - val_y1_output_mae: 119.9806 - val_y2_output_loss: 258.0638 - val_y2_output_mae: 15.2660
# Epoch 162/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6951.6099 - y1_output_loss: 5584.3960 - y1_output_mae: 61.7408 - y2_output_loss: 1312.0826 - y2_output_mae: 27.7458 - val_loss: 4332.4248 - val_y1_output_loss: 1522.4095 - val_y1_output_mae: 36.0273 - val_y2_output_loss: 2832.4558 - val_y2_output_mae: 49.3861
# Epoch 163/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 7142.8550 - y1_output_loss: 6111.9531 - y1_output_mae: 61.1657 - y2_output_loss: 1437.2390 - y2_output_mae: 32.0199 - val_loss: 26026.9941 - val_y1_output_loss: 25684.7070 - val_y1_output_mae: 155.9647 - val_y2_output_loss: 460.1847 - val_y2_output_mae: 17.7182
# Epoch 164/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9511.9551 - y1_output_loss: 7510.1304 - y1_output_mae: 66.3876 - y2_output_loss: 1803.3278 - y2_output_mae: 35.1883 - val_loss: 8517.8584 - val_y1_output_loss: 7420.3359 - val_y1_output_mae: 83.3438 - val_y2_output_loss: 1121.8390 - val_y2_output_mae: 28.5534
# Epoch 165/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 7391.0488 - y1_output_loss: 6579.3413 - y1_output_mae: 65.7068 - y2_output_loss: 1309.8711 - y2_output_mae: 29.7032 - val_loss: 5565.5181 - val_y1_output_loss: 4760.9502 - val_y1_output_mae: 66.3501 - val_y2_output_loss: 808.2162 - val_y2_output_mae: 24.4167
# Epoch 166/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4887.5928 - y1_output_loss: 3026.6729 - y1_output_mae: 46.6727 - y2_output_loss: 1682.5586 - y2_output_mae: 33.9888 - val_loss: 4452.1445 - val_y1_output_loss: 4023.1929 - val_y1_output_mae: 60.5110 - val_y2_output_loss: 459.3500 - val_y2_output_mae: 16.6467
# Epoch 167/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4356.7803 - y1_output_loss: 4122.1455 - y1_output_mae: 47.9320 - y2_output_loss: 1197.4747 - y2_output_mae: 24.9339 - val_loss: 6139.2124 - val_y1_output_loss: 5850.0767 - val_y1_output_mae: 73.7937 - val_y2_output_loss: 297.8304 - val_y2_output_mae: 15.1472
# Epoch 168/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 41663.1406 - y1_output_loss: 19279.4863 - y1_output_mae: 107.9865 - y2_output_loss: 24653.7227 - y2_output_mae: 119.8290 - val_loss: 234915.3281 - val_y1_output_loss: 37231.2383 - val_y1_output_mae: 188.0080 - val_y2_output_loss: 198674.2188 - val_y2_output_mae: 435.1392
# Epoch 169/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 282933.2500 - y1_output_loss: 217809.0469 - y1_output_mae: 388.4529 - y2_output_loss: 86707.5625 - y2_output_mae: 250.2146 - val_loss: 1291387.0000 - val_y1_output_loss: 1142977.0000 - val_y1_output_mae: 1044.8877 - val_y2_output_loss: 152804.9219 - val_y2_output_mae: 381.9261
# Epoch 170/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 379503.9688 - y1_output_loss: 258804.3281 - y1_output_mae: 421.4260 - y2_output_loss: 107420.9844 - y2_output_mae: 266.7171 - val_loss: 133226.2656 - val_y1_output_loss: 21488.4277 - val_y1_output_mae: 142.8376 - val_y2_output_loss: 112113.3516 - val_y2_output_mae: 327.0962
# Epoch 171/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 339507.6875 - y1_output_loss: 264782.1875 - y1_output_mae: 432.6895 - y2_output_loss: 72909.2344 - y2_output_mae: 208.7319 - val_loss: 97315.2969 - val_y1_output_loss: 96486.0781 - val_y1_output_mae: 303.4690 - val_y2_output_loss: 1124.4807 - val_y2_output_mae: 29.5405
# Epoch 172/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 70866.4844 - y1_output_loss: 44538.8008 - y1_output_mae: 166.0052 - y2_output_loss: 23883.4023 - y2_output_mae: 131.8004 - val_loss: 113129.4297 - val_y1_output_loss: 44690.1875 - val_y1_output_mae: 206.1070 - val_y2_output_loss: 68820.0156 - val_y2_output_mae: 256.1612
# Epoch 173/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 74180.6953 - y1_output_loss: 39247.7109 - y1_output_mae: 168.2788 - y2_output_loss: 33899.3438 - y2_output_mae: 156.8484 - val_loss: 137083.6875 - val_y1_output_loss: 125787.9766 - val_y1_output_mae: 346.3106 - val_y2_output_loss: 11824.2715 - val_y2_output_mae: 105.3804
# Epoch 174/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 77582.4922 - y1_output_loss: 66105.7031 - y1_output_mae: 219.7990 - y2_output_loss: 9823.6152 - y2_output_mae: 78.8685 - val_loss: 160454.6719 - val_y1_output_loss: 160686.4219 - val_y1_output_mae: 391.4725 - val_y2_output_loss: 410.9794 - val_y2_output_mae: 16.8058
# Epoch 175/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 77540.2266 - y1_output_loss: 75139.6016 - y1_output_mae: 229.0592 - y2_output_loss: 3005.2563 - y2_output_mae: 44.6845 - val_loss: 549994.9375 - val_y1_output_loss: 544353.0000 - val_y1_output_mae: 720.8738 - val_y2_output_loss: 7734.2515 - val_y2_output_mae: 84.7669
# Epoch 176/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 152609.8125 - y1_output_loss: 110791.8125 - y1_output_mae: 258.0100 - y2_output_loss: 36938.4531 - y2_output_mae: 144.3978 - val_loss: 105353.9766 - val_y1_output_loss: 14122.6426 - val_y1_output_mae: 115.3391 - val_y2_output_loss: 91560.4297 - val_y2_output_mae: 295.5591
# Epoch 177/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 37868.5000 - y1_output_loss: 10215.4043 - y1_output_mae: 81.0237 - y2_output_loss: 26594.7910 - y2_output_mae: 132.9478 - val_loss: 20576.0352 - val_y1_output_loss: 4156.0093 - val_y1_output_mae: 61.5954 - val_y2_output_loss: 16536.4375 - val_y2_output_mae: 124.5224
# Epoch 178/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 20541.3477 - y1_output_loss: 1905.6130 - y1_output_mae: 32.6434 - y2_output_loss: 18171.0215 - y2_output_mae: 116.8087 - val_loss: 8961.6885 - val_y1_output_loss: 2272.4199 - val_y1_output_mae: 44.9891 - val_y2_output_loss: 6734.2563 - val_y2_output_mae: 78.5290
# Epoch 179/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 79879.9844 - y1_output_loss: 2089.4568 - y1_output_mae: 37.0436 - y2_output_loss: 76659.9531 - y2_output_mae: 219.9481 - val_loss: 98099.3984 - val_y1_output_loss: 3352.0515 - val_y1_output_mae: 55.2960 - val_y2_output_loss: 95020.3906 - val_y2_output_mae: 301.1060
# Epoch 180/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 289756.9375 - y1_output_loss: 2963.2905 - y1_output_mae: 42.2095 - y2_output_loss: 275459.7812 - y2_output_mae: 426.3991 - val_loss: 59322.6445 - val_y1_output_loss: 4578.9312 - val_y1_output_mae: 64.7867 - val_y2_output_loss: 54915.1562 - val_y2_output_mae: 228.7379
# Epoch 181/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 139480.9219 - y1_output_loss: 4632.7412 - y1_output_mae: 57.3643 - y2_output_loss: 131903.2812 - y2_output_mae: 308.0051 - val_loss: 42926.0547 - val_y1_output_loss: 1223.5570 - val_y1_output_mae: 31.9429 - val_y2_output_loss: 41804.6016 - val_y2_output_mae: 199.4680
# Epoch 182/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 48153.7773 - y1_output_loss: 5117.3818 - y1_output_mae: 61.0074 - y2_output_loss: 42088.5078 - y2_output_mae: 172.5952 - val_loss: 43399.8594 - val_y1_output_loss: 10264.8955 - val_y1_output_mae: 98.3606 - val_y2_output_loss: 33320.7109 - val_y2_output_mae: 177.5452
# Epoch 183/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9896.7979 - y1_output_loss: 4285.9775 - y1_output_mae: 53.2649 - y2_output_loss: 5421.4893 - y2_output_mae: 56.5790 - val_loss: 10905.2178 - val_y1_output_loss: 5905.4038 - val_y1_output_mae: 73.9308 - val_y2_output_loss: 5068.6431 - val_y2_output_mae: 67.6798
# Epoch 184/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 50182.4219 - y1_output_loss: 20489.8555 - y1_output_mae: 122.7930 - y2_output_loss: 29401.2695 - y2_output_mae: 148.5289 - val_loss: 1918.9816 - val_y1_output_loss: 193.8564 - val_y1_output_mae: 12.2530 - val_y2_output_loss: 1742.7139 - val_y2_output_mae: 37.6575
# Epoch 185/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 19362.0527 - y1_output_loss: 10372.8301 - y1_output_mae: 80.7492 - y2_output_loss: 8432.3232 - y2_output_mae: 74.1160 - val_loss: 3278.9675 - val_y1_output_loss: 1838.4799 - val_y1_output_mae: 39.8872 - val_y2_output_loss: 1467.8325 - val_y2_output_mae: 33.9721
# Epoch 186/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 12630.4922 - y1_output_loss: 2850.5166 - y1_output_mae: 43.5816 - y2_output_loss: 10932.7188 - y2_output_mae: 78.7759 - val_loss: 27729.1465 - val_y1_output_loss: 930.0131 - val_y1_output_mae: 27.3830 - val_y2_output_loss: 26856.6348 - val_y2_output_mae: 159.6631
# Epoch 187/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 121519.4688 - y1_output_loss: 20265.5195 - y1_output_mae: 90.5061 - y2_output_loss: 103804.5156 - y2_output_mae: 276.1395 - val_loss: 419910.9688 - val_y1_output_loss: 339823.6875 - val_y1_output_mae: 569.5494 - val_y2_output_loss: 81635.3281 - val_y2_output_mae: 279.0702
# Epoch 188/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 705475.0000 - y1_output_loss: 409956.0938 - y1_output_mae: 528.4572 - y2_output_loss: 350594.8125 - y2_output_mae: 453.5406 - val_loss: 5098373.5000 - val_y1_output_loss: 1233058.6250 - val_y1_output_mae: 1085.4653 - val_y2_output_loss: 3883164.0000 - val_y2_output_mae: 1926.3020
# Epoch 189/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1797557.1250 - y1_output_loss: 1060502.5000 - y1_output_mae: 859.9505 - y2_output_loss: 758754.1250 - y2_output_mae: 702.1818 - val_loss: 1448155.1250 - val_y1_output_loss: 420023.9062 - val_y1_output_mae: 633.4672 - val_y2_output_loss: 1033020.6250 - val_y2_output_mae: 993.5274
# Epoch 190/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 942720.1875 - y1_output_loss: 303450.9375 - y1_output_mae: 430.5985 - y2_output_loss: 637775.6250 - y2_output_mae: 682.3585 - val_loss: 29463.0742 - val_y1_output_loss: 20331.5117 - val_y1_output_mae: 138.7195 - val_y2_output_loss: 9282.3076 - val_y2_output_mae: 92.8351
# Epoch 191/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 537654.3125 - y1_output_loss: 414080.3125 - y1_output_mae: 564.1408 - y2_output_loss: 108576.2266 - y2_output_mae: 274.0685 - val_loss: 638853.6250 - val_y1_output_loss: 605434.1250 - val_y1_output_mae: 760.3837 - val_y2_output_loss: 35808.2578 - val_y2_output_mae: 184.5668
# Epoch 192/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 282375.9062 - y1_output_loss: 215761.3281 - y1_output_mae: 391.4255 - y2_output_loss: 56125.3633 - y2_output_mae: 202.4823 - val_loss: 104585.7266 - val_y1_output_loss: 90304.4219 - val_y1_output_mae: 293.6154 - val_y2_output_loss: 14639.5938 - val_y2_output_mae: 117.0917
# Epoch 193/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 38872.3867 - y1_output_loss: 29898.4590 - y1_output_mae: 137.0293 - y2_output_loss: 7880.6235 - y2_output_mae: 71.6530 - val_loss: 5176.8228 - val_y1_output_loss: 4915.4780 - val_y1_output_mae: 67.3352 - val_y2_output_loss: 289.6351 - val_y2_output_mae: 14.8799
# Epoch 194/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 7258.8452 - y1_output_loss: 5637.5864 - y1_output_mae: 59.2953 - y2_output_loss: 1459.5576 - y2_output_mae: 29.9288 - val_loss: 1241.6130 - val_y1_output_loss: 895.1315 - val_y1_output_mae: 26.8347 - val_y2_output_loss: 344.9063 - val_y2_output_mae: 15.6993
# Epoch 195/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3135.8003 - y1_output_loss: 2073.7876 - y1_output_mae: 37.1529 - y2_output_loss: 1042.6064 - y2_output_mae: 26.1589 - val_loss: 1828.7938 - val_y1_output_loss: 1268.1289 - val_y1_output_mae: 32.6707 - val_y2_output_loss: 566.8697 - val_y2_output_mae: 18.1850
# Epoch 196/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1236.4852 - y1_output_loss: 676.4041 - y1_output_mae: 21.5049 - y2_output_loss: 549.6519 - y2_output_mae: 19.4537 - val_loss: 852.0221 - val_y1_output_loss: 287.3039 - val_y1_output_mae: 14.2647 - val_y2_output_loss: 562.3813 - val_y2_output_mae: 19.8867
# Epoch 197/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1077.4908 - y1_output_loss: 262.9868 - y1_output_mae: 13.4596 - y2_output_loss: 798.1202 - y2_output_mae: 23.1791 - val_loss: 696.7123 - val_y1_output_loss: 165.5521 - val_y1_output_mae: 11.7282 - val_y2_output_loss: 538.8113 - val_y2_output_mae: 17.6485
# Epoch 198/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1274.6554 - y1_output_loss: 480.4839 - y1_output_mae: 17.0071 - y2_output_loss: 834.3333 - y2_output_mae: 23.6155 - val_loss: 6440.1631 - val_y1_output_loss: 1241.1860 - val_y1_output_mae: 32.2945 - val_y2_output_loss: 5201.1006 - val_y2_output_mae: 69.0556
# Epoch 199/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3300.4087 - y1_output_loss: 777.9154 - y1_output_mae: 23.7525 - y2_output_loss: 2492.6982 - y2_output_mae: 41.4191 - val_loss: 500.7738 - val_y1_output_loss: 235.5931 - val_y1_output_mae: 13.0810 - val_y2_output_loss: 264.9776 - val_y2_output_mae: 14.4948
# Epoch 200/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3882.6147 - y1_output_loss: 366.2634 - y1_output_mae: 15.6880 - y2_output_loss: 3386.3289 - y2_output_mae: 50.1735 - val_loss: 956.3743 - val_y1_output_loss: 580.0360 - val_y1_output_mae: 21.2298 - val_y2_output_loss: 374.4429 - val_y2_output_mae: 16.1352

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'val_loss', 'val_y1_output_loss', 'val_y1_output_mae', 'val_y2_output_loss', 'val_y2_output_mae', 'y1_output_loss', 'y1_output_mae', 'y2_output_loss', 'y2_output_mae'])

# %%
# Evaluamos el modelo
results = model.evaluate(X_test, [y1_test, y2_test], verbose=0)

test_loss, y1_loss, y2_loss, test_mae_heating, test_mae_cooling = results

print(f"Total Test Loss: {test_loss:.4f}")
print(f"Heating Loss: {y1_loss:.4f}, Cooling Loss: {y2_loss:.4f}")
print(f"Test MAE for Heating Load: {test_mae_heating:.4f} Wh")
print(f"Test MAE for Cooling Load: {test_mae_cooling:.4f} Wh")
# Out:
# Total Test Loss: 956.3743
# Heating Loss: 580.0360, Cooling Loss: 374.4429
# Test MAE for Heating Load: 21.2298 Wh
# Test MAE for Cooling Load: 16.1352 Wh

# %%
import matplotlib.pyplot as plt


print(history.history.keys())

# ---- Graficamos el loss, que en este caso decidimos que fuera el MSE
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Total Training Loss')
plt.plot(history.history['val_loss'], label='Total Validation Loss')
plt.plot(history.history['y1_output_loss'], label='Heating Training Loss')
plt.plot(history.history['val_y1_output_loss'], label='Heating Validation Loss')
plt.plot(history.history['y2_output_loss'], label='Cooling Training Loss')
plt.plot(history.history['val_y2_output_loss'], label='Cooling Validation Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# Graficamos el MAE
plt.figure(figsize=(10, 6))
plt.plot(history.history['y1_output_mae'], label='Heating Training MAE')
plt.plot(history.history['val_y1_output_mae'], label='Heating Validation MAE')
plt.plot(history.history['y2_output_mae'], label='Cooling Training MAE')
plt.plot(history.history['val_y2_output_mae'], label='Cooling Validation MAE')
plt.title('Model MAE over Epochs')
plt.xlabel('Epochs')
plt.ylabel('MAE (Wh)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# dict_keys(['loss', 'val_loss', 'val_y1_output_loss', 'val_y1_output_mae', 'val_y2_output_loss', 'val_y2_output_mae', 'y1_output_loss', 'y1_output_mae', 'y2_output_loss', 'y2_output_mae'])

# %%
# Realizar predicciones
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

#Como tenemos dos targets, las predicciones hay que separarlas
y_train_pred_heating = y_pred_train[0].flatten()
y_train_pred_cooling = y_pred_train[1].flatten()

y_test_pred_heating = y_pred_test[0].flatten()
y_test_pred_cooling = y_pred_test[1].flatten()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
#Metricas de performance para heating

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score

def regression_metrics(y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(root_mean_squared_error(y_true, y_pred))
    return r2, mae, rmse

# Metricas train
r2_train_heat, mae_train_heat, rmse_train_heat = regression_metrics(y1_train, y_train_pred_heating)
r2_train_cool, mae_train_cool, rmse_train_cool = regression_metrics(y2_train, y_train_pred_cooling)
print("=== Train Performance ===")
print(f"Heating Load: R²={r2_train_heat:.3f}, MAE={mae_train_heat:.3f}, RMSE={rmse_train_heat:.3f}")
print(f"Cooling Load: R²={r2_train_cool:.3f}, MAE={mae_train_cool:.3f}, RMSE={rmse_train_cool:.3f}")

# metricas test
r2_test_heat, mae_test_heat, rmse_test_heat = regression_metrics(y1_test, y_test_pred_heating)
r2_test_cool, mae_test_cool, rmse_test_cool = regression_metrics(y2_test, y_test_pred_cooling)
print("\n=== Test Performance ===")
print(f"Heating Load: R²={r2_test_heat:.3f}, MAE={mae_test_heat:.3f}, RMSE={rmse_test_heat:.3f}")
print(f"Cooling Load: R²={r2_test_cool:.3f}, MAE={mae_test_cool:.3f}, RMSE={rmse_test_cool:.3f}")
# Out:
# === Train Performance ===
# Heating Load: R²=-4.989, MAE=21.712, RMSE=4.958
# Cooling Load: R²=-3.436, MAE=16.684, RMSE=4.466
#
# === Test Performance ===
# Heating Load: R²=-4.572, MAE=21.230, RMSE=4.909
# Cooling Load: R²=-3.053, MAE=16.135, RMSE=4.402

# %% [markdown]
# #### Cross Validation

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models

def build_model(input_dim):
    input_layer = layers.Input(shape=(input_dim,))
    
    # Capas compartidas
    x = layers.Dense(128, activation='relu')(input_layer)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    
    # Heating
    h = layers.Dense(64, activation='relu')(x)
    h = layers.Dropout(0.2)(h)
    h = layers.Dense(32, activation='relu')(h)
    y1 = layers.Dense(1, name='heating_output')(h)
    
    # Cooling
    c = layers.Dense(64, activation='relu')(x)
    c = layers.Dropout(0.2)(c)
    c = layers.Dense(32, activation='relu')(c)
    y2 = layers.Dense(1, name='cooling_output')(c)
    
    model = models.Model(inputs=input_layer, outputs=[y1, y2])
    model.compile(optimizer='adam', loss='mse')
    return model

# %%
from sklearn.model_selection import KFold

from sklearn.preprocessing import StandardScaler
from numpy import sqrt

#KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

r2_heat, r2_cool = [], []
mae_heat, mae_cool = [], []
rmse_heat, rmse_cool = [], []

for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    print(f"\n Fold {fold+1}")
    
    # Split data
    X_train, X_val = X[train_idx], X[val_idx]
    y_train_heat, y_val_heat = df['Y1'][train_idx], df['Y1'][val_idx]
    y_train_cool, y_val_cool = df['Y2'][train_idx], df['Y2'][val_idx]
    
    # Scale inputs
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    
    # Build & train model
    model = build_model(X.shape[1])
    model.fit(
        X_train, [y_train_heat, y_train_cool],
        epochs=80, batch_size=32, verbose=0
    )
    
    # Predict
    y_pred_heat, y_pred_cool = model.predict(X_val, verbose=0)
    
    # Flatten
    y_pred_heat, y_pred_cool = y_pred_heat.flatten(), y_pred_cool.flatten()
    
    # Compute metrics
    r2_heat.append(r2_score(y_val_heat, y_pred_heat))
    r2_cool.append(r2_score(y_val_cool, y_pred_cool))
    mae_heat.append(mean_absolute_error(y_val_heat, y_pred_heat))
    mae_cool.append(mean_absolute_error(y_val_cool, y_pred_cool))
    rmse_heat.append(sqrt(mean_squared_error(y_val_heat, y_pred_heat)))
    rmse_cool.append(sqrt(mean_squared_error(y_val_cool, y_pred_cool)))
# Out:
#  Fold 1
#
#  Fold 2
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x34fc48670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#  Fold 3
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x35a23c700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#  Fold 4
#
#  Fold 5

# %%
print("\n=== Cross-Validation Results ===")
print(f"Heating Load: R2={np.mean(r2_heat):.3f}±{np.std(r2_heat):.3f}, "
      f"MAE={np.mean(mae_heat):.3f}, RMSE={np.mean(rmse_heat):.3f}")
print(f"Cooling Load: R2={np.mean(r2_cool):.3f}±{np.std(r2_cool):.3f}, "
      f"MAE={np.mean(mae_cool):.3f}, RMSE={np.mean(rmse_cool):.3f}")
# Out:
# === Cross-Validation Results ===
# Heating Load: R2=-4160.667±6751.462, MAE=392.374, RMSE=402.844
# Cooling Load: R2=-151.166±191.261, MAE=85.116, RMSE=90.438

# %% [markdown]
# ## Tuneo de hiperparametros
#
# Especificamente diseniado para redes neuronales

# %%
# Random Serach
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models, optimizers

df = pd.read_csv("ENB2012_data.csv")
X_full = df[['X1','X2','X3','X4','X5','X6','X7','X8']].values
y1_full = df['Y1'].values
y2_full = df['Y2'].values

scaler = StandardScaler()
X_full = scaler.fit_transform(X_full)


X_train_full, X_test_full, y1_train_full, y1_test_full, y2_train_full, y2_test_full = train_test_split(
    X_full, y1_full, y2_full, test_size=0.2, random_state=42
)


# Definimos el contructor del modelo

def build_random_model(params, input_dim):
    input_layer = layers.Input(shape=(input_dim,))
    
    # compartidas
    x = input_layer
    for i in range(params['n_shared_layers']):
        x = layers.Dense(params['n_shared_units'], activation='relu')(x)
        x = layers.Dropout(params['dropout_rate'])(x)
    
    # Heating 
    h = layers.Dense(params['n_shared_units']//2, activation='relu')(x)
    y1 = layers.Dense(1, name='heating_output')(h)
    
    # Cooling 
    c = layers.Dense(params['n_shared_units']//2, activation='relu')(x)
    y2 = layers.Dense(1, name='cooling_output')(c)
    
    model = models.Model(inputs=input_layer, outputs=[y1, y2])
    
    opt = optimizers.Adam(learning_rate=params['learning_rate'])
    model.compile(
        optimizer=opt,
        loss={'heating_output': 'mse', 'cooling_output': 'mse'},
        metrics={'heating_output': 'mae', 'cooling_output': 'mae'}
    )
    
    return model


# Espacio para el random search

param_distributions = {
    'n_shared_layers': [1, 2, 3],
    'n_shared_units': [32, 64, 128, 256],
    'dropout_rate': [0.0, 0.1, 0.2, 0.3, 0.4],
    'learning_rate': [1e-4, 5e-4, 1e-3, 5e-3],
    'batch_size': [16, 32, 64]
}


n_trials = 5
results = []

print("\n Empezamos Random Search")
for i in range(n_trials):
    params = {k: random.choice(v) for k, v in param_distributions.items()}
    print(f"\nTrial {i+1}/{n_trials} with params: {params}")
    
    X_train_rs, X_val_rs, y1_train_rs, y1_val_rs, y2_train_rs, y2_val_rs = train_test_split(
        X_train_full, y1_train_full, y2_train_full, test_size=0.2, random_state=i
    )
    
    model = build_random_model(params, X_train_rs.shape[1])
    history = model.fit(
        X_train_rs, [y1_train_rs, y2_train_rs],
        validation_data=(X_val_rs, [y1_val_rs, y2_val_rs]),
        epochs=50, batch_size=params['batch_size'], verbose=0
    )
    
    val_loss = np.mean(history.history['val_loss'][-5:])
    results.append((params, val_loss))
    print(f"Validation Loss: {val_loss:.4f}")

# Resultados
results.sort(key=lambda x: x[1])
print("\n Results")
for rank, (params, loss) in enumerate(results, 1):
    print(f"{rank:2d}) Val Loss={loss:.4f} | Params={params}")

best_params, best_loss = results[0]
print("\n Mejor configuracion:")
print(best_params)
print(f"Validation Loss: {best_loss:.4f}")
# Out:
#  Empezamos Random Search
#
# Trial 1/5 with params: {'n_shared_layers': 1, 'n_shared_units': 128, 'dropout_rate': 0.3, 'learning_rate': 0.001, 'batch_size': 16}
# Validation Loss: 20.5411
#
# Trial 2/5 with params: {'n_shared_layers': 2, 'n_shared_units': 256, 'dropout_rate': 0.1, 'learning_rate': 0.001, 'batch_size': 16}
# Validation Loss: 208.4407
#
# Trial 3/5 with params: {'n_shared_layers': 3, 'n_shared_units': 32, 'dropout_rate': 0.2, 'learning_rate': 0.0005, 'batch_size': 64}
# Validation Loss: 825.1167
#
# Trial 4/5 with params: {'n_shared_layers': 2, 'n_shared_units': 32, 'dropout_rate': 0.1, 'learning_rate': 0.0001, 'batch_size': 64}
# Validation Loss: 1130.7197
#
# Trial 5/5 with params: {'n_shared_layers': 2, 'n_shared_units': 32, 'dropout_rate': 0.0, 'learning_rate': 0.0001, 'batch_size': 32}
# Validation Loss: 1097.1293
#
#  Results
#  1) Val Loss=20.5411 | Params={'n_shared_layers': 1, 'n_shared_units': 128, 'dropout_rate': 0.3, 'learning_rate': 0.001, 'batch_size': 16}
#  2) Val Loss=208.4407 | Params={'n_shared_layers': 2, 'n_shared_units': 256, 'dropout_rate': 0.1, 'learning_rate': 0.001, 'batch_size': 16}
#  3) Val Loss=825.1167 | Params={'n_shared_layers': 3, 'n_shared_units': 32, 'dropout_rate': 0.2, 'learning_rate': 0.0005, 'batch_size': 64}
#  4) Val Loss=1097.1293 | Params={'n_shared_layers': 2, 'n_shared_units': 32, 'dropout_rate': 0.0, 'learning_rate': 0.0001, 'batch_size': 32}
#  5) Val Loss=1130.7197 | Params={'n_shared_layers': 2, 'n_shared_units': 32, 'dropout_rate': 0.1, 'learning_rate': 0.0001, 'batch_size': 64}
#
#  Mejor configuracion:
# {'n_shared_layers': 1, 'n_shared_units': 128, 'dropout_rate': 0.3, 'learning_rate': 0.001, 'batch_size': 16}
# Validation Loss: 20.5411

# %% [markdown]
# #### Algunas referencias
#
# - https://keras.io/guides/sequential_model/
# - https://keras.io/api/layers/activations/
# - https://keras.io/optimizers/
# - https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-gauss&learningRate=0.03&regularizationRate=0.003&noise=20&networkShape=4&seed=0.82538&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=regression&initZero=false&hideText=false
